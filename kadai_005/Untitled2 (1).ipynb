# %%
print(1+2)
# Out:
# 3

# %%
print("ジュースで乾杯！")
else:

# %%
age = 19 # 年齢

if age < 20:
    # 未成年の場合
    print("ジュースで乾杯！")
else:
    # 成年の場合
    print("お酒で乾杯！")
# Out:
# ジュースで乾杯！

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)

print(45 + 1.8)
print(3 - 1.2)
print(15 * 0.6)
print(3 / 0.3)
print(45 % 0.8)
# Out:
# 63
# 18
# 90
# 10.0
# 5
# 46.8
# 1.8
# 9.0
# 10.0
# 0.1999999999999975

# %%
print(type(30/3))
# Out:
# <class 'float'>

# %%
print("今日の天気は" + "晴れ")
print("今日の天気は" "曇り")
# Out:
# 今日の天気は晴れ
# 今日の天気は曇り

# %%
print("降水確率" + str(50) + "%")
# Out:
# 降水確率50%

# %%
print("晴れ" * 5)
# Out:
# 晴れ晴れ晴れ晴れ晴れ

# %%
 user_name = "yamazaki"
 print(user_name)
# Out:
# yamazaki

# %%
#整数型と浮動小数点の足し算
number1 = 5
number2 = 2.5
print(number1 + number2)

#文字列型と文字列型の連結
last_name = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 7.5
# 侍太郎

# %%
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
print("台形の面積は" + str((10 +20) * 5 / 2) + "cm")
# Out:
# 台形の面積は75.0cm
